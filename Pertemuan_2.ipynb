# %% [markdown]
# <a href="https://colab.research.google.com/github/qulbiazz/244107020050-mobile-course/blob/main/Pertemuan_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# D1. Pengenalan Python: Pengolahan Citra Dasar dan memahami channel warna pada OpenCV dan konversinya

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d7ad2e73-8f81-4223-b63f-0b017c51077f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d7ad2e73-8f81-4223-b63f-0b017c51077f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np

img = cv.imread('Ktp.jpg')
cv2_imshow(img)

print("Resolusi gambar: ", img.shape[1], " x ", img.shape[0])
# Out:
# <PIL.Image.Image image mode=RGB size=720x452>
# Resolusi gambar:  720  x  452

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np

img = cv.imread('Ktp.jpg')
plt.imshow(img) #format bgr

print("Resolusi gambar: ", img.shape[1], " x ", img.shape[0])
# Out:
# Resolusi gambar:  720  x  452

# %%
img_gray = cv.imread('Ktp.jpg', cv.IMREAD_GRAYSCALE)

#TANPA CMAP
plt.subplot(1,2,1)
plt.imshow(img_gray)
plt.title("Tanpa cmap")

#DENGAN CMAP
plt.subplot(1,2,2)
plt.imshow(img_gray, cmap='magma')
plt.title("Dengan cmap")

plt.show()

# %%
imgRGB=cv.cvtColor(img, cv.COLOR_BGR2RGB) #koneversi bgr to rgb
img_output=cv.resize(imgRGB,(347,229))
plt.imshow(img_output)

# %%
imgFlip=cv.flip(img_output,1)
plt.imshow(imgFlip)

# %%
imgFlip=cv.flip(img_output,1)

#ukuran canvas lebih besar
fig=plt.figure(figsize=(10,10))
ax=fig.add_subplot(1,1,1)
ax.imshow(imgFlip)

# %% [markdown]
# 6.	Membuat bentuk Geometri 2D dari OpenCV. Diawali dengan pembuatan black image dengan tipe data int16.

# %%
black_img = np.zeros(shape=(530,530,3),dtype=np.int16)
plt.imshow(black_img)

# %%
#perhatikan koordinat titik2 pt1 dan pt2
cv.rectangle(black_img,pt1=(290,0),pt2=(520,130),color=(0,0,255),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(250,250),pt2=(350,350),color=(255,0,0),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(150,150),radius=60,color=(0,255,0),thickness=8)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(400,400),radius=50,color=(0,255,0),thickness=-1)
cv.line(black_img,pt1=(0,0),pt2=(530,530),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
black_img = black_img.astype(np.uint8)

font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img, text='PCVK is fun!', org=(10, 500), fontFace=font, fontScale=2,
           color=(255, 255, 0), thickness=3, lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# 1. Inisialisasi kanvas hitam
black_img = np.zeros(shape=(530, 530, 3), dtype=np.uint8)

# 2. Tentukan titik-titik sudut poligon (format [x, y], tipe int32)
# Contoh membuat bentuk segitiga/poligon 4 titik:
pts = np.array([[100, 300], [200, 150], [400, 150], [350, 400]], dtype=np.int32)
pts = pts.reshape((-1, 1, 2))

# 3. Gambar poligon ke kanvas
cv.polylines(black_img, [pts], isClosed=True, color=(0, 255, 0), thickness=5)

# 4. Tampilkan hasil
plt.imshow(black_img)
plt.axis('off')
plt.show()

# %% [markdown]
# **PERTANYAAN** PRAKTIKUM

# %% [markdown]
# 1. Tampilkan satu citra bebas menggunakan cv2_imshow() dan plt.imshow() tanpa konversi warna apa pun. Mengapa hasilnya berbeda? Buktikan dengan mencetak nilai satu piksel yang sama dari kedua cara pembacaan tersebut.

# %%
import cv2 as cv
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# Baca citra
img = cv.imread('Ktp.jpg')

# Tampilkan dengan cv2_imshow
cv2_imshow(img)

# Tampilkan dengan plt.imshow
plt.imshow(img)

# Cetak pembuktian nilai satu piksel yang sama
print("Pembuktian", img[100, 100])
# Out:
# <PIL.Image.Image image mode=RGB size=720x452>
# Pembuktian [235 215 184]

# %% [markdown]
# Perbedaan tampilan terjadi karena urutan kanal warna default yang digunakan oleh kedua pustaka berbeda:
#
# - OpenCV (cv2_imshow / cv.imread) membaca dan menampilkan citra dalam format BGR (Blue, Green, Red).
#
# - Matplotlib (plt.imshow) mengasumsikan dan menampilkan array piksel dalam format RGB (Red, Green, Blue).

# %% [markdown]
# 2. Buat kanvas hitam berukuran sama dengan tipe data int16 dan int32. Bandingkan dtype, min(), max(), dan nbytes keduanya. Apakah tampilannya berbeda? Apakah ukuran memorinya berbeda? Jelaskan alasannya.

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Buat dua kanvas hitam
canvas1 = np.zeros((530, 530, 3), dtype=np.int16)
canvas2 = np.zeros((530, 530, 3), dtype=np.int32)

# 2. Cetak perbandingan sesuai instruksi
print("Dtype  :", canvas1.dtype, "vs", canvas2.dtype)
print("Min    :", canvas1.min(), "vs", canvas2.min())
print("Max    :", canvas1.max(), "vs", canvas2.max())
print("Nbytes :", canvas1.nbytes, "vs", canvas2.nbytes)

# 3. Tampilkan
plt.imshow(canvas1)
plt.show()

plt.imshow(canvas2)
plt.show()
# Out:
# Dtype  : int16 vs int32
# Min    : 0 vs 0
# Max    : 0 vs 0
# Nbytes : 1685400 vs 3370800

# %% [markdown]
# Tampilan: Sama persis (keduanya hitam) karena semua nilai pikselnya bernilai 0.
#
# Ukuran Memori (nbytes): Berbeda. int32 berukuran 2x lebih besar daripada int16 karena int32 membutuhkan 4 byte per elemen, sedangkan int16 hanya membutuhkan 2 byte per elemen.

# %% [markdown]
# 3. Apa kegunaan baris from google.colab.patches import cv2_imshow, dan mengapa cv2.imshow() bawaan OpenCV tidak dapat dipakai di Google Colab?

# %% [markdown]
# Fungsi bawaan cv2.imshow() memerlukan antarmuka GUI (layar desktop lokal) untuk memunculkan jendela baru, sedangkan Google Colab adalah server cloud tanpa monitor (headless). Baris from google.colab.patches import cv2_imshow digunakan sebagai pengganti agar gambar dapat ditampilkan langsung di dalam sel notebook tanpa memicu crash.

# %% [markdown]
# 4. Citra yang dibaca dengan skimage.io.imread() ditampilkan berdampingan dengan hasil cv2.cvtColor(img, cv2.COLOR_BGR2RGB) atas citra yang sama. Manakah yang menampilkan warna sebenarnya, dan manakah yang kanalnya tertukar? Buktikan dengan nilai piksel, bukan dengan pengamatan visual saja.

# %%
import cv2
import skimage.io
import matplotlib.pyplot as plt

# 1. Baca citra menggunakan skimage (menghasilkan RGB)
img_skimage = skimage.io.imread('Ktp.jpg')

# 2. Baca dengan OpenCV (BGR) lalu konversi ke RGB
img_cv = cv2.imread('Ktp.jpg')
img_cv_rgb = cv2.cvtColor(img_cv, cv2.COLOR_BGR2RGB)

# 3. Tampilkan berdampingan
plt.subplot(1, 2, 1)
plt.title("skimage.io.imread")
plt.imshow(img_skimage)

plt.subplot(1, 2, 2)
plt.title("OpenCV to RGB")
plt.imshow(img_cv_rgb)
plt.show()

# 4. Buktikan nilai piksel di koordinat yang sama (misal y=100, x=100)
print("Piksel skimage    :", img_skimage[100, 100])
print("Piksel OpenCV RGB :", img_cv_rgb[100, 100])
# Out:
# Piksel skimage    : [184 215 235]
# Piksel OpenCV RGB : [184 215 235]

# %% [markdown]
# Keduanya menampilkan warna sebenarnya secara visual jika ditampilkan menggunakan plt.imshow(), dan tidak ada kanal yang tertukar di antara keduanya.
#
# Alasannya:
#
# - skimage.io.imread() membaca citra langsung dalam format RGB.
#
# - cv2.imread() membaca citra dalam format BGR, namun setelah diubah dengan cv2.cvtColor(img, cv2.COLOR_BGR2RGB), susunan kanalnya berubah menjadi RGB.
#
# Karena keduanya kini berformat RGB, nilai susunan pikselnya menjadi identik.

# %% [markdown]
# 5. Setelah citra ditampilkan dengan figsize yang jauh lebih besar, apakah nilai img.shape ikut berubah? Jelaskan perbedaan antara mengubah ukuran citra dan mengubah ukuran tampilan.

# %% [markdown]
# Mengubah Ukuran Tampilan (figsize):
#
# - Hanya mengubah ukuran kanvas atau area jendela plot di layar (rendering).
#
# - Data array gambar di dalam memori tetap utuh, sehingga img.shape (jumlah baris, kolom, dan kanal piksel) tidak berubah sama sekali.
#
# - Menggunakan pustaka visualisasi, misalnya plt.figure(figsize=(15, 15)).
#
# Mengubah Ukuran Citra (Resizing):
#
# - Mengubah dimensi matriks data citra secara permanen melalui proses interpolasi (menambah atau mengurangi piksel).
#
# - Nilai img.shape dan ukuran memori citra pasti ikut berubah.
#
# - Menggunakan fungsi pemrosesan citra, misalnya cv2.resize(img, (lebar, tinggi)).

# %% [markdown]
# TUGAS PRAKTIKUM - Penerapan

# %% [markdown]
# Berdasarkan praktikum bagian 1 dan 2 kerjakan beberapa tugas berikut :

# %% [markdown]
# 1.	Tampilkan citra hanya pada kombinasi kanal Merah-Biru dan kanal Hijau-Biru saja, dengan kanal yang tidak dipakai dinolkan. Susun keduanya berdampingan dalam satu figure yang diberi judul.

# %%
import cv2 as cv
import matplotlib.pyplot as plt

# Baca citra dan ubah ke RGB
img = cv.imread('Ktp.jpg')
img_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)

# Kanal Merah-Biru (nolkan kanal Hijau / indeks 1)
img_rb = img_rgb.copy()
img_rb[:, :, 1] = 0

# Kanal Hijau-Biru (nolkan kanal Merah / indeks 0)
img_gb = img_rgb.copy()
img_gb[:, :, 0] = 0

# Tampilkan berdampingan
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(img_rb)
plt.title("Kanal Merah - Biru")
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(img_gb)
plt.title("Kanal Hijau - Biru")
plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# 2.	Tampilkan citra dalam tiga bentuk pencerminan: vertikal, horizontal, dan keduanya, dalam satu figure berisi tiga subplot yang masing-masing diberi label.

# %%
import cv2 as cv
import matplotlib.pyplot as plt

img = cv.imread('Ktp.jpg')
img_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)

# Operasi pencerminan (flip)
flip_vertikal = cv.flip(img_rgb, 0)
flip_horizontal = cv.flip(img_rgb, 1)
flip_keduanya = cv.flip(img_rgb, -1)

# Tampilkan dalam satu figure dengan 3 subplot
plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
plt.imshow(flip_vertikal)
plt.title("Pencerminan Vertikal")
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(flip_horizontal)
plt.title("Pencerminan Horizontal")
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(flip_keduanya)
plt.title("Pencerminan Keduanya")
plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# 3.	Gambarkan sebuah rectangle dan sebuah circle pada bagian wajah / badan dari foto aktivitas Anda sendiri (bukan pasfoto), lalu tambahkan teks berisi nama Anda dengan pilihan font, ukuran, dan warna yang Anda tentukan sendiri.

# %%
import cv2 as cv
import matplotlib.pyplot as plt

# 1. Baca citra aktivitas dan konversi ke RGB
path_foto = '/content/drive/MyDrive/PCVK/foto_aktivitas_qulbi.jpeg'
img = cv.imread(path_foto)
img_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)

h, w = img_rgb.shape[:2]

# 2. Gambar Circle tepat di area wajah -> warna Hijau (0, 255, 0)
# Wajah berada di sekitar horizontal tengah (46.5%) dan vertikal 43%
pusat_wajah = (int(w * 0.465), int(h * 0.43))
radius_wajah = int(w * 0.12)
tebal_garis = max(2, int(w * 0.005))

cv.circle(img_rgb, center=pusat_wajah, radius=radius_wajah,
          color=(0, 255, 0), thickness=tebal_garis)

# 3. Gambar Rectangle di area badan/hoodie -> warna Biru (0, 120, 255)
# Meliputi pundak kiri hingga pinggang kanan
pt1_badan = (int(w * 0.28), int(h * 0.47))
pt2_badan = (int(w * 0.65), int(h * 0.85))

cv.rectangle(img_rgb, pt1=pt1_badan, pt2=pt2_badan,
             color=(0, 120, 255), thickness=tebal_garis)

# 4. Tambahkan Teks Nama di atas kepala -> warna Kuning Emas (255, 215, 0)
font = cv.FONT_HERSHEY_SIMPLEX
skala_font = w / 500
posisi_teks = (int(w * 0.35), int(h * 0.28))

cv.putText(img_rgb, text='QULBI', org=posisi_teks, fontFace=font,
           fontScale=skala_font, color=(255, 215, 0),
           thickness=tebal_garis + 1, lineType=cv.LINE_AA)

# 5. Tampilkan hasil
plt.figure(figsize=(8, 8))
plt.imshow(img_rgb)
plt.axis('off')
plt.show()

# %% [markdown]
# 4.	Menampilkan gambar dalam bentuk warna merah, hijau dan biru

# %%
import cv2 as cv
import matplotlib.pyplot as plt

# Baca dan ubah ke RGB
img = cv.imread('Ktp.jpg')
img_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)

# Ambil matriks 2D masing-masing kanal
r = img_rgb[:, :, 0]
g = img_rgb[:, :, 1]
b = img_rgb[:, :, 2]

# Tampilkan menggunakan Colormap Matplotlib bawaan
plt.figure(figsize=(10, 6))

plt.subplot(2, 3, 1)
plt.imshow(r, cmap='Reds_r')
plt.title("Kanal Merah")
plt.axis('off')

plt.subplot(2, 3, 2)
plt.imshow(g, cmap='Greens_r')
plt.title("Kanal Hijau")
plt.axis('off')

plt.subplot(2, 3, 3)
plt.imshow(b, cmap='Blues_r')
plt.title("Kanal Biru")
plt.axis('off')

plt.subplot(2, 3, 5)
plt.imshow(img_rgb)
plt.title("Citra Asli (RGB)")
plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# TUGAS PRAKTIKUM - Analisa

# %% [markdown]
# Rumuskan satu pertanyaan tentang citra digital yang dapat Anda jawab menggunakan kode dari modul ini. Contoh pertanyaan: berapa persen piksel pada foto KTM Anda yang lebih gelap dari nilai 100? apakah mengecilkan lalu membesarkan citra mengubah rata-rata intensitasnya? Tuliskan pertanyaan Anda, rancangan program, data hasilnya, dan kesimpulan Anda.

# %% [markdown]
# Pertanyaan
# - Berapa persentase area/piksel berpenetrasi gelap (intensitas piksel rata-rata $< 100$) pada foto KTP/KTM, dan bagaimana distribusi dominasi warna (Red, Green, Blue) rata-ratanya?
#
# Rancangan Program
# - Membaca citra menggunakan OpenCV (cv.imread) lalu mengubah representasi warna ke RGB (cv.COLOR_BGR2RGB).
# - Menghitung rata-rata intensitas per piksel di ketiga kanal $\frac(R + G + B)/3 sebagai representasi tingkat kecerahan (brightness).
# - Melakukan thresholding boolean untuk menghitung rasio jumlah piksel bernilai $< 100$ terhadap total seluruh piksel citra.
# - Menghitung nilai rata-rata tiap kanal individual (R, G, dan B) untuk melihat kecenderungan warna latar/dokumen.

# %%
import cv2 as cv
import numpy as np

# 1. Baca citra dan ubah format BGR ke RGB
img = cv.imread('Ktp.jpg')
img_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)

# 2. Hitung intensitas rata-rata per piksel
intensitas = np.mean(img_rgb, axis=2)

# 3. Hitung persentase piksel gelap (< 100)
total_piksel = intensitas.size
piksel_gelap = np.sum(intensitas < 100)
persentase_gelap = (piksel_gelap / total_piksel) * 100

# 4. Hitung rata-rata tiap kanal warna
avg_r = np.mean(img_rgb[:, :, 0])
avg_g = np.mean(img_rgb[:, :, 1])
avg_b = np.mean(img_rgb[:, :, 2])

# Tampilkan data hasil perhitungan
print("=== HASIL PENGUKURAN CITRA ===")
print(f"Dimensi citra (Shape)       : {img_rgb.shape}")
print(f"Total seluruh piksel        : {total_piksel:,} piksel")
print(f"Jumlah piksel gelap (< 100) : {piksel_gelap:,} piksel")
print(f"Persentase piksel gelap     : {persentase_gelap:.2f} %")
print(f"Rata-rata Intensitas Red    : {avg_r:.2f}")
print(f"Rata-rata Intensitas Green  : {avg_g:.2f}")
print(f"Rata-rata Intensitas Blue   : {avg_b:.2f}")
# Out:
# === HASIL PENGUKURAN CITRA ===
# Dimensi citra (Shape)       : (452, 720, 3)
# Total seluruh piksel        : 325,440 piksel
# Jumlah piksel gelap (< 100) : 28,225 piksel
# Persentase piksel gelap     : 8.67 %
# Rata-rata Intensitas Red    : 158.52
# Rata-rata Intensitas Green  : 187.25
# Rata-rata Intensitas Blue   : 204.93

# %% [markdown]
# TUGAS PRAKTIKUM - Aplikasi

# %% [markdown]
# Pada bagian ini, Anda hanya diperbolehkan memakai fungsi yang telah dipelajari pada modul ini: pembacaan berkas, pengirisan, cv2.resize, cv2.flip, cv2.cvtColor, fungsi penggambaran OpenCV, serta pembuatan kanvas dengan NumPy. Selain itu, program harus bersifat adaptif, dimana setiap ukuran, posisi, atau ketebalan harus dihitung dari ukuran citra masukan, bukan ditulis sebagai angka tetap pada kode program.
#
# Studi Kasus 1: Panitia sebuah kegiatan perlu membubuhkan label identitas pada ratusan foto dokumentasi. Foto berasal dari beberapa kamera dan ponsel, sehingga ukurannya bermacam-macam. Label harus terlihat seimbang pada semua foto tanpa disetel satu per satu. Fungsi yang sama dikenakan pada dua citra berbeda ukuran. Tinggi bar dan ukuran huruf ikut menyesuaikan, sehingga proporsinya tetap sama.
#
# Studi Kasus 2: Marketplace seperti Tokopedia dan Shopee menampilkan foto produk dalam bingkai persegi 1:1. Foto penjual yang berukuran potrait atau lanskap akan terpotong atau terlihat tidak proporsional bila diunggah begitu saja. Bangun program yang mengubah foto berukuran apa pun menjadi thumbnail persegi tanpa mengubah rasio aslinya, dengan sisa ruang diisi kanvas berwarna. Dalam hal ini, rasio asli tetap terjaga, citra terpasang tepat di tengah kanvas, tambahkan logo nama toko berukuran proporsional pada gambar

# %%
import cv2 as cv
import matplotlib.pyplot as plt

# 1. Fungsi penambahan label identitas adaptif
def tambah_label_adaptif(img, teks="Dokumentasi PCVK - 2026"):
    output = img.copy()
    h, w = output.shape[:2]

    # Rumus adaptif dari soal: bar = tinggi // 12
    tinggi_bar = h // 12
    font_scale = (tinggi_bar / 50) * 0.55
    thickness = max(1, int(tinggi_bar / 30))

    # Buat bar hitam solid di bagian bawah
    cv.rectangle(output, pt1=(0, h - tinggi_bar), pt2=(w, h), color=(0, 0, 0), thickness=-1)

    # Letakkan teks di sisi kiri bawah di dalam bar
    posisi_x = int(w * 0.02)
    posisi_y = int(h - (tinggi_bar * 0.35))
    cv.putText(output, teks, (posisi_x, posisi_y), cv.FONT_HERSHEY_SIMPLEX,
               font_scale, (255, 255, 255), thickness, cv.LINE_AA)

    return output, tinggi_bar

# 2. Baca kedua citra pemandangan (lanskap & potret)
# Sesuaikan path/nama file dengan file yang telah diunggah di Colab Anda
path_lanskap = '/content/drive/MyDrive/PCVK/pemandangan_lanskap.jpg'  # foto pemandangan horizontal
path_potret  = '/content/drive/MyDrive/PCVK/pemandangan_potret.jpg'    # foto pemandangan vertikal

img_lanskap = cv.imread(path_lanskap)
img_potret = cv.imread(path_potret)

# Ubah ke RGB
img_lanskap = cv.cvtColor(img_lanskap, cv.COLOR_BGR2RGB)
img_potret = cv.cvtColor(img_potret, cv.COLOR_BGR2RGB)

# 3. Sesuaikan ukuran masukan sesuai gambar acuan (900x600 dan 480x760)
img1 = cv.resize(img_lanskap, (900, 600))
img2 = cv.resize(img_potret, (480, 760))

# 4. Beri label adaptif pada kedua citra
hasil1, bar1 = tambah_label_adaptif(img1)
hasil2, bar2 = tambah_label_adaptif(img2)

# 5. Tampilkan dalam susunan 2x2 seperti pada gambar acuan
plt.figure(figsize=(11, 10))

# Baris 1: Citra Lanskap
plt.subplot(2, 2, 1)
plt.imshow(img1)
plt.title(f"Masukan {img1.shape[1]} x {img1.shape[0]} px")
plt.axis('off')

plt.subplot(2, 2, 2)
plt.imshow(hasil1)
plt.title(f"Keluaran: bar = {img1.shape[0]}//12 = {bar1} px")
plt.axis('off')

# Baris 2: Citra Potret
plt.subplot(2, 2, 3)
plt.imshow(img2)
plt.title(f"Masukan {img2.shape[1]} x {img2.shape[0]} px")
plt.axis('off')

plt.subplot(2, 2, 4)
plt.imshow(hasil2)
plt.title(f"Keluaran: bar = {img2.shape[0]}//12 = {bar2} px")
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

def buat_thumbnail_persegi(img, ukuran_target=600, warna_bg=(240, 240, 240)):
    h_asli, w_asli = img.shape[:2]

    # 1. Hitung rasio adaptif
    skala = min(ukuran_target / w_asli, ukuran_target / h_asli)
    w_baru = int(w_asli * skala)
    h_baru = int(h_asli * skala)

    img_resized = cv.resize(img, (w_baru, h_baru), interpolation=cv.INTER_AREA)

    # 2. Buat kanvas persegi 1:1
    kanvas = np.full((ukuran_target, ukuran_target, 3), warna_bg, dtype=np.uint8)

    # 3. Tempel tepat di tengah kanvas
    x_offset = (ukuran_target - w_baru) // 2
    y_offset = (ukuran_target - h_baru) // 2
    kanvas[y_offset:y_offset + h_baru, x_offset:x_offset + w_baru] = img_resized

    return kanvas

# Baca citra lanskap dari Google Drive
path_lanskap = '/content/drive/MyDrive/PCVK/pemandangan_lanskap.jpg'
img_lanskap = cv.imread(path_lanskap)
img_lanskap_rgb = cv.cvtColor(img_lanskap, cv.COLOR_BGR2RGB)

# Buat thumbnail persegi 1:1
hasil_thumbnail = buat_thumbnail_persegi(img_lanskap_rgb, ukuran_target=600)

# Tampilkan gambar bersih tanpa judul teks/keterangan
plt.figure(figsize=(6, 6))
plt.imshow(hasil_thumbnail)
plt.axis('off')
plt.show()
